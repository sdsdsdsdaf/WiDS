# %%
import optuna

# %%
# !pip install optuna-dashboard

# %%
from optuna.storages import JournalStorage
from optuna.storages.journal import JournalFileBackend

storage = JournalStorage(
    JournalFileBackend("gbsa_journal.log")
)

study = optuna.load_study(study_name="gbsa_survival", storage=storage)

# %%
df = study.trials_dataframe()
df.head()
# Out:
#    number     value             datetime_start          datetime_complete  \
# 0       0  0.853891 2026-03-10 02:36:51.423395 2026-03-10 02:36:54.149104
# 1       1  0.826541 2026-03-10 02:36:54.163556 2026-03-10 02:37:14.563975
# 2       2  0.840792 2026-03-10 02:37:14.577484 2026-03-10 02:37:40.103866
# 3       3  0.815916 2026-03-10 02:37:40.109356 2026-03-10 02:38:08.688309
# 4       4  0.811980 2026-03-10 02:38:08.693393 2026-03-10 02:38:18.170271
#
#                 duration  params_ccp_alpha  params_dropout_rate  \
# 0 0 days 00:00:02.725709      1.092959e-06             0.305926
# 1 0 days 00:00:20.400419      1.520469e-06             0.260034
# 2 0 days 00:00:25.526382      5.107754e-03             0.353429
# 3 0 days 00:00:28.578953      1.659603e-08             0.318205
# 4 0 days 00:00:09.476878      1.059532e-02             0.003476
#
#    params_learning_rate  params_max_depth params_max_features  \
# 0              0.154036                 4                 0.3
# ...

# %%
df_sort = df.sort_values("value", ascending=False)
df_top20 = df_sort.head(20).drop(columns=["datetime_start", "datetime_complete", "duration", "state", "number",])
df_top20.to_csv("gbsa_top20.csv", index=False)
df_top20.head()
# Out:
#         value  params_ccp_alpha  params_dropout_rate  params_learning_rate  \
# 180  0.932300      3.387171e-06             0.010036              0.183752
# 238  0.931827      1.185231e-08             0.014365              0.110844
# 236  0.931186      1.893673e-08             0.004627              0.116992
# 229  0.930481      4.793502e-07             0.002454              0.088458
# 153  0.929977      8.280965e-05             0.009795              0.105618
#
#      params_max_depth params_max_features  params_max_leaf_nodes  \
# 180                 5                 1.0                    NaN
# 238                 6                None                    NaN
# 236                 6                None                    NaN
# 229                 5                None                    NaN
# 153                 5                 1.0                   31.0
#
#      params_min_impurity_decrease  params_min_samples_leaf  \
# 180                      0.001367                       20
# ...

# %%
df.describe()
# Out:
#            number       value                 datetime_start  \
# count  300.000000  300.000000                            300
# mean   149.500000    0.890715  2026-03-10 02:59:20.307571712
# min      0.000000    0.811980     2026-03-10 02:36:51.423395
# 25%     74.750000    0.872844  2026-03-10 02:45:38.395148544
# 50%    149.500000    0.895145  2026-03-10 02:57:07.270555648
# 75%    224.250000    0.913399  2026-03-10 03:08:47.111454208
# max    299.000000    0.932300     2026-03-10 03:33:43.992171
# std     86.746758    0.027661                            NaN
#
#                    datetime_complete                   duration  \
# count                            300                        300
# mean   2026-03-10 02:59:31.677410816  0 days 00:00:11.369839196
# min       2026-03-10 02:36:54.149104     0 days 00:00:01.120865
# 25%    2026-03-10 02:45:43.253001728  0 days 00:00:02.405780500
# 50%    2026-03-10 02:57:13.500994560  0 days 00:00:05.179631500
# ...
